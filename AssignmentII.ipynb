# %% [markdown]
# <a href="https://colab.research.google.com/github/Girishgh7/Cart_OCR/blob/main/AssignmentII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Q1 Students 🧑‍🎓
#
# ### 1.Read the student dataset dat.csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/DSC 316/dat.csv")
#to print first 10 values
df.head(10)
#to print last 10 values
df.tail(10)
#to print all values
print(df)
# Out:
#     Stud ID  Age  Weight  Height
# 20       21   22      56     154
# 21       22   22      56     158
# 22       23   22      51     148
# 23       24   22      51     149
# 24       25   22      51     152
# 25       26   22      55     155
# 26       27   21      55     156
# 27       28   21      55     156
# 28       29   21      50     152
# 29       30   21      50     152

# %% [markdown]
# (b) Find the summary statistics of each variable

# %%
df.info()
summary=df.describe()
print(summary)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Stud ID  30 non-null     int64
#  1   Age      30 non-null     int64
#  2   Weight   30 non-null     int64
#  3   Height   30 non-null     int64
# dtypes: int64(4)
# memory usage: 1.1 KB
#          Stud ID        Age     Weight      Height
# count  30.000000  30.000000  30.000000   30.000000
# mean   15.500000  20.900000  53.166667  154.666667
# std     8.803408   0.803012   3.301863    3.565479
# min     1.000000  20.000000  45.000000  148.000000
# 25%     8.250000  20.000000  50.250000  152.000000
# 50%    15.500000  21.000000  55.000000  155.000000
# 75%    22.750000  21.750000  55.000000  156.000000
# max    30.000000  22.000000  60.000000  162.000000

# %% [markdown]
# Plot the graph of significant variables such as age, weight, and height

# %%
#ploting Age of the data
plt.figure(figsize=(5, 5))
plt.hist(df.Age,bins=10,color='blue')
plt.title('Age of the data')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
#Ploting Weight of the data
plt.figure(figsize=(5, 5))
plt.hist(df.Weight,bins=10,color='red')
plt.title('Weight of the data')
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.show()
#Plotting Height of the dataset
plt.figure(figsize=(5, 5))
plt.hist(df.Height,bins=9,color='green')
plt.title('Height of the data')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.show()

# %%
#ploting weight and height
plt.scatter(df['Weight'],df['Height'])
plt.xlabel('Weight')
plt.ylabel('height')
plt.show()

# %%
#Ploting age and height
plt.scatter(df['Age'],df['Height'])
plt.xlabel('Age')
plt.ylabel('Height')
plt.show()

# %%
# looking correaltion between coloums using seaborn
import seaborn as sns
sns.pairplot(df)
plt.show()

# %%
#FINDING correaltion in data
correlation_matrix = df.corr()#making correlation matrix
print(correlation_matrix)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)#usig heatmaps to visulize the correaltion
plt.title('Correlation Matrix')
plt.show()
# Out:
#           Stud ID       Age    Weight    Height
# Stud ID  1.000000  0.504859 -0.145321  0.124140
# Age      0.504859  1.000000  0.084535 -0.180656
# Weight  -0.145321  0.084535  1.000000  0.268495
# Height   0.124140 -0.180656  0.268495  1.000000

# %% [markdown]
# ### What can we observe:
#
#
# 1.   *Age and height have negative correaltion height and weight have postive correlation*
# 2.   *Age and Weight have some postive realtion*
#
# ## Overall
# ### Age and Weight ,Weight and Height have postive realtion while Age and Height have negative realtion

# %% [markdown]
# # Q2 **Salary** 💵

# %% [markdown]
# 1.   Read the salary data set
# 2.   Check whether any null value or outlier in the data set

# %%
salary=pd.read_csv("/content/drive/MyDrive/DSC 316/Salaries.csv")
salary.head()
salary.tail()
print(salary)
# Out:
#     salary  years  gender
# 0     3400     21       1
# 1     3917     27       2
# 2     2686     13       1
# 3     2598     12       1
# 4     4024     27       1
# 5     3245     20       2
# 6     3653     24       2
# 7     4387     32       1
# 8     3015     16       1
# 9     3316     19       1
# 10    4438     33       2
# 11    3993     26       1
# 12    3628     22       1
# 13    4040     28       1
# 14    4056     29       2
# 15    2821     16       1
# 16    2645     13       2
# 17    3029     18       1
# 18    3408     22       2
# 19    3588     24       2
# 20    3061     19       2
# 21    2280     11       2
# 22    1965      8       1
# 23    2333     11       1
# 24    3440     23       2
# 25    2993     19       2

# %%
salary.info()
plt.boxplot(salary.salary)
#from box plot to check for any outliners in salary
plt.show()
plt.boxplot(salary.years)
#from box plot to check for any outliners in years
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   salary  26 non-null     int64
#  1   years   26 non-null     int64
#  2   gender  26 non-null     int64
# dtypes: int64(3)
# memory usage: 752.0 bytes

# %%
salary.isnull().values.any()#check any values are null/missing
# Out:
# False

# %% [markdown]
# 3.    Sketch the box plot/histogram and check whether the distribution of the data is symmetric or
# skewed

# %%
#boxploting for years ,salary
plt.figure(figsize=(5, 5))
plt.boxplot(salary.salary)
plt.show()
plt.figure(figsize=(5, 5))
plt.boxplot(salary.years)
plt.show()

# %%
#scatter for years and salary
plt.scatter(salary.years,salary.salary)
plt.xlabel('years')
plt.ylabel('Salary')
plt.title("Years V/s salary")
plt.show()

# %%
#counting how many 1 and 2 are there
x=salary['gender'].value_counts()[1]
y=salary['gender'].value_counts()[2]
print("The number of 1 and two are:\t",x,y)
plt.hist(salary.gender,bins=3,color='skyblue')
plt.show()
# Out:
# The number of 1 and two are:	 14 12

# %%
sns.barplot(x='gender',y='salary',data=salary,ci=None)
sns.title("gender v/s pay")
plt.show()
# Out:
# <ipython-input-77-16051406bf5c>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='gender',y='salary',data=salary,ci=None)

# %% [markdown]
#  **Conclusion 💵**
#
# 1.   Their is a Linear realtionship with years and salary(more years== more money)
# 2.   No outliers or missing values found in the data
# 3.  Gender population 1= 14 and  2= 12
# 4. Gender salary is **almost** equal

# %% [markdown]
# # Q3 Distribution 📊

# %% [markdown]
# Q.IV
# 1. Generate a random sample of size 100 from poisson distribution and check its normality
# 2. Generate a random sample of size 100 from normal distribution and check its normality

# %%
import numpy as np
import random
import scipy as sp
from scipy.stats import stats
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
#Generate a random sample of size 100 from poisson distribution and check its normality
sample = np.random.poisson(lam=10, size=100)
plt.hist(sample,bins=20,edgecolor='black')
plt.title('Histogram of Random Sample from Poisson Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
## making qq plot to check if it lines with normal
## using sp.stats.probplot to check normality remember to use scipy.probplot
sp.stats.probplot(sample,dist="norm",plot=plt)
plt.title("QQ Plot")
plt.show()

# %%
# Generate a random sample of size 100 from normal distribution and check its normality
#sample=np.random.normal(loc=0,scale=1,size=100) for standard normal distribution
sample=np.random.normal(loc=4,scale=3,size=100)
plt.hist(sample,bins=20,edgecolor='red')
plt.title('Histogram of Random Sample from Normal Distribution')
plt.show()
sp.stats.probplot(sample,dist="norm",plot=plt)
plt.title("QQ Plot")
plt.show()

# %% [markdown]
# # Q4 **Economy**🏰

# %% [markdown]
# 1. Read the csv file educ_figdp_1_Data.csv file
# 2. Find out the headers of the columns
# 3. Put it in a table format.
# 4. Select a subset of the data by filtering with condition that value > 6.5
# 5. Filter the missing value and clean the data set.
# 6. Obtain the summary statistics about the cleaned data.
# 7. Sort the data using any keyword heading
# 8. Group the data under the value “GEO”
# 9. Rearrange the data with country name as index.
# 10. Rank the country in terms of values in descending order.

# %%
import pandas as pd
eco=pd.read_csv("/content/drive/MyDrive/DSC 316/educ_figdp_1_Data.csv")
eco.head()
# Out:
#    TIME                                   GEO  \
# 0  2002  European Union (current composition)
# 1  2002  European Union (current composition)
# 2  2002  European Union (current composition)
# 3  2002  European Union (current composition)
# 4  2002  European Union (current composition)
#
#                                             INDIC_ED        UNIT Value  \
# 0  Total public expenditure on education as % of ...  Percentage     5
# 1  Total public expenditure on education as % of ...  Percentage  1.13
# 2  Total public expenditure on education as % of ...  Percentage  2.27
# 3  Total public expenditure on education as % of ...  Percentage  1.12
# 4  Total public expenditure on education as % of ...  Percentage  0.49
#
#   Flag and Footnotes
# 0                  e
# 1                  e
# 2                  e
# 3                  e
# 4                  e

# %%
headers=eco.columns
print(headers)
# Out:
# Index(['TIME', 'GEO', 'INDIC_ED', 'UNIT', 'Value', 'Flag and Footnotes'], dtype='object')

# %%
dt=pd.DataFrame(eco)
print(dt)
#Question is very Questioning
# Out:
#       TIME                                   GEO  \
# 0     2002  European Union (current composition)
# 1     2002  European Union (current composition)
# 2     2002  European Union (current composition)
# 3     2002  European Union (current composition)
# 4     2002  European Union (current composition)
# ...    ...                                   ...
# 2192  2011                         United States
# 2193  2011                         United States
# 2194  2011                         United States
# 2197  2011                                 Japan
# 2198  2011                                 Japan
#
#                                                INDIC_ED        UNIT  Value  \
# 0     Total public expenditure on education as % of ...  Percentage   5.00
# 1     Total public expenditure on education as % of ...  Percentage   1.13
# 2     Total public expenditure on education as % of ...  Percentage   2.27
# ...

# %%
eco.info()
summary=eco.describe()
print(summary)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TIME                2200 non-null   int64
#  1   GEO                 2200 non-null   object
#  2   INDIC_ED            2200 non-null   object
#  3   UNIT                2200 non-null   object
#  4   Value               2200 non-null   object
#  5   Flag and Footnotes  972 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 103.2+ KB
#               TIME
# count  2200.000000
# mean   2006.500000
# std       2.872934
# min    2002.000000
# 25%    2004.000000
# 50%    2006.500000
# 75%    2009.000000
# max    2011.000000

# %%
print(eco.isnull().values.any())
eco.dropna(inplace=True)
print(eco)
print(eco.isnull().values.any())
#removing any null values
# Out:
# True
#       TIME                                   GEO  \
# 0     2002  European Union (current composition)
# 1     2002  European Union (current composition)
# 2     2002  European Union (current composition)
# 3     2002  European Union (current composition)
# 4     2002  European Union (current composition)
# ...    ...                                   ...
# 2192  2011                         United States
# 2193  2011                         United States
# 2194  2011                         United States
# 2197  2011                                 Japan
# 2198  2011                                 Japan
#
#                                                INDIC_ED        UNIT  Value  \
# 0     Total public expenditure on education as % of ...  Percentage   5.00
# 1     Total public expenditure on education as % of ...  Percentage   1.13
# 2     Total public expenditure on education as % of ...  Percentage   2.27
# ...

# %% [markdown]
# #getting the summary of the data

# %%
eco.info()
summary=eco.describe()#used to descirbe the data sets
print(summary)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 938 entries, 0 to 2198
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TIME                938 non-null    int64
#  1   GEO                 938 non-null    object
#  2   INDIC_ED            938 non-null    object
#  3   UNIT                938 non-null    object
#  4   Value               938 non-null    float64
#  5   Flag and Footnotes  938 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 51.3+ KB
#               TIME       Value
# count   938.000000  938.000000
# mean   2006.340085    2.147377
# std       2.844327    1.792880
# min    2002.000000    0.110000
# 25%    2004.000000    0.980000
# 50%    2006.000000    1.410000
# 75%    2009.000000    2.560000
# max    2011.000000    8.810000

# %%
eco['Value']=pd.to_numeric(eco['Value'],errors='coerce')
subset=eco[eco["Value"]>6.5]#making a subet to arrange everyone >6.5
print(subset)
# Out:
#       TIME      GEO                                           INDIC_ED  \
# 50    2002  Denmark  Total public expenditure on education as % of ...
# 95    2002   Cyprus  Total public expenditure on education as % of ...
# 175   2002  Iceland  Total public expenditure on education as % of ...
# 185   2002   Norway  Total public expenditure on education as % of ...
# 315   2003   Cyprus  Total public expenditure on education as % of ...
# 395   2003  Iceland  Total public expenditure on education as % of ...
# 535   2004   Cyprus  Total public expenditure on education as % of ...
# 615   2004  Iceland  Total public expenditure on education as % of ...
# 710   2005  Denmark  Total public expenditure on education as % of ...
# 755   2005   Cyprus  Total public expenditure on education as % of ...
# 780   2005    Malta  Total public expenditure on education as % of ...
# 835   2005  Iceland  Total public expenditure on education as % of ...
# ...

# %%
x=eco.describe()
print(x)
# Out:
#               TIME       Value
# count   938.000000  938.000000
# mean   2006.340085    2.147377
# std       2.844327    1.792880
# min    2002.000000    0.110000
# 25%    2004.000000    0.980000
# 50%    2006.000000    1.410000
# 75%    2009.000000    2.560000
# max    2011.000000    8.810000

# %%
eco['Value']=pd.to_numeric(eco['Value'],errors='coerce')
eco_sorted=eco.sort_values(by='Value',ascending=False)# In ascending order put True insted
print(eco_sorted[['GEO', 'Value']])
# Out:
#           GEO  Value
# 1810  Denmark   8.81
# 2030  Denmark   8.75
# 1590  Denmark   8.74
# 50    Denmark   8.44
# 490   Denmark   8.43
# ...       ...    ...
# 2185  Albania    NaN
# 2186  Albania    NaN
# 2187  Albania    NaN
# 2188  Albania    NaN
# 2189  Albania    NaN
#
# [2200 rows x 2 columns]

# %%
#Group the data under the value “GEO”
#Sort the data using any keyword heading#what keyword
#using Value for ranking
eco_sorted=eco.sort_values(by='Value',ascending=False)
print(eco_sorted[['GEO', 'Value']])
# Out:
#                  GEO  Value
# 1810         Denmark   8.81
# 2030         Denmark   8.75
# 1590         Denmark   8.74
# 50           Denmark   8.44
# 710          Denmark   8.30
# ...              ...    ...
# 1494  United Kingdom   0.29
# 179          Iceland   0.29
# 74            Greece   0.17
# 294           Greece   0.11
# 514           Greece   0.11
#
# [938 rows x 2 columns]

# %% [markdown]
# ### using Value for ranking

# %%
eco_rearranged = pd.DataFrame(eco.set_index('GEO'))
print(eco_rearranged)
# Out:
#                                       TIME  \
# GEO
# European Union (current composition)  2002
# European Union (current composition)  2002
# European Union (current composition)  2002
# European Union (current composition)  2002
# European Union (current composition)  2002
# ...                                    ...
# United States                         2011
# United States                         2011
# United States                         2011
# Japan                                 2011
# Japan                                 2011
#
#                                                                                INDIC_ED  \
# GEO
# European Union (current composition)  Total public expenditure on education as % of ...
# European Union (current composition)  Total public expenditure on education as % of ...
# European Union (current composition)  Total public expenditure on education as % of ...
# ...
